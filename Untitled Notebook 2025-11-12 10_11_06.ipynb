# %%
# %fs ls 'abfss://demoajinkya@deacourseajinkya.dfs.core.windows.net/'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_course_ext_dl_ajinkya
URL 'abfss://demoajinkya@deacourseajinkya.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `dea-course-ext-sc`)
