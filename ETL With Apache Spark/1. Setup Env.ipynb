# %% [markdown]
# Setup the project environment

# %% [markdown]
# > 1. Access the contaner gizmobox

# %%
# %fs ls 'abfss://gizmoboxajinkya@deacourseajinkya.dfs.core.windows.net/landing/operational_data/'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_course_ext_dl_demo
URL 'abfss://gizmoboxajinkya@deacourseajinkya.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `dea-course-ext-sc`)

# %% [markdown]
# Create the catalog dizmoboxajinkya

# %%
# %sql
show catalogs

# %%
# %sql

CREATE CATALOG IF NOT EXISTS gizmobox
MANAGED LOCATION 'abfss://gizmoboxajinkya@deacourseajinkya.dfs.core.windows.net/'
COMMENT 'CATALOG FOR GIZMOBOX PROJECT'

# %% [markdown]
# CREATE SCHEMAS FOR LANDING BRONZE SILVER AND GOLD

# %%
# %sql
SELECT current_catalog();

# %%
# %sql
USE CATALOG gizmobox

# %%
# %sql
CREATE  SCHEMA IF NOT EXISTS landing
    MANAGED LOCATION 'abfss://gizmoboxajinkya@deacourseajinkya.dfs.core.windows.net/landing';

# %%
# %sql
SHOW SCHEMAS

# %%
# %sql
CREATE  SCHEMA IF NOT EXISTS landing
    MANAGED LOCATION 'abfss://gizmoboxajinkya@deacourseajinkya.dfs.core.windows.net/landing';
CREATE  SCHEMA IF NOT EXISTS bronze
    MANAGED LOCATION 'abfss://gizmoboxajinkya@deacourseajinkya.dfs.core.windows.net/landing';
CREATE  SCHEMA IF NOT EXISTS gold
    MANAGED LOCATION 'abfss://gizmoboxajinkya@deacourseajinkya.dfs.core.windows.net/landing';
CREATE  SCHEMA IF NOT EXISTS silver
    MANAGED LOCATION 'abfss://gizmoboxajinkya@deacourseajinkya.dfs.core.windows.net/landing';

# %% [markdown]
# create volume

# %%
# %sql
USE CATALOG gizmobox;
USE SCHEMA landing;
CREATE EXTERNAL  VOLUME  IF NOT EXISTS operational_data
    LOCATION 'abfss://gizmoboxajinkya@deacourseajinkya.dfs.core.windows.net/landing/operational_data';

# %%
# %fs ls /Volumes/gizmobox/landing/operational_data/customers
